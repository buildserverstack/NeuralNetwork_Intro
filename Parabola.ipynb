# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
xs=np.arange(-10,10,0.25)

# %%
def quad(x):
    return 3*x**2-7*x+40

# %%
ys=quad(xs)

# %%
plt.plot(xs,ys)
plt.show()
